# %%
import pandas as pd

df1 = pd.read_csv("5_1.csv")
df1.plot()
df2 = pd.read_csv("5_2.csv")
df2.plot()
df3 = pd.DataFrame(columns = ["Eth", "sex"])
df3['Eth'] = df1['nlat mean']
df3['sex'] = df2['nlat mean']
df3.plot()
print(df1['nlat mean'].mean())
print(df2['nlat mean'].mean())
print(df1['nlat stdDev'].mean())
print(df2['nlat stdDev'].mean())
# Out:
# 0.8813405811202292
# 0.8646816455599975
# 0.11554870571147632
# 0.1392322431143924
